# %% [markdown]
# # Capability Test Notebook
#
# Testing NotebookEdit tool

# %%
import sys
import platform

print(f"Python: {sys.version}")
print(f"Platform: {platform.platform()}")
print("NotebookEdit tool works!")

# %%
# This cell was inserted by NotebookEdit!
print("Cell insertion works too!")
